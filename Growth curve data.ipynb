# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

file = pd.read_excel('C:\\Users\Anushka\Downloads\Growth Curve.xlsx')
# x =  np.linspace(-10, 10, 100)
# y =  np.linspace(10, 100, 100)
x = file['Time (min)']
y = file['Mean OD']
plt.errorbar(file['Time (min)'], file['Mean OD'], yerr=file['Std Dev'], fmt='o', capsize=5, ecolor='blue', label='Measurements')
plt.plot(x, y)
plt.xlabel('time (min)', fontsize = 20)
plt.ylabel('OD', fontsize = 20 )
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.title('Growth Curve with Error Bars')
# Out:
# Text(0.5, 1.0, 'Growth Curve with Error Bars')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.optimize #import curve_fit
file = pd.read_excel ("C:\\Users\Anushka\Downloads\Growth Curve.xlsx")
x = file ['Time (min)']
y = file ['Mean OD']
yerr = file['Std Dev']
def logistic (t,K,r,t0):
    return K/(1 + np.exp (-r *(t-t0)))
initial_guess = [max(od), 0.1, np.median(time)]
popt, _ = curve_fit(logistic, time, od ,p0 = initial_guess)
K,r,t0 = popt
time_fit = np.linspace(min(time), max(time), 200)
od_fit = logistic(time_fit, *popt)
plt.Figure (figsize = (9,5))
plt.errorbar(file['Time (min)'], file['Mean OD'], yerr = file['Std Dev'], fmt= 'o', label= 'Observed Data',capsize= 5, color= 'green')
plt.plot(time_fit, od_fit, label= 'Logistic Fit',color= 'purple')
plt.xlabel ('Time(min)', fontsize= 20)
plt.ylabel ('OD', fontsize= 20)
plt.title ('Bacterial Growth Curve (Logistic Model)')
plt.legend()
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
file = pd.read_excel("C:\\Users\Anushka\Downloads\Growth Curve.xlsx")
x = file ['Time (min)']
y1 = file ['OD1']
y2 = file ['OD2']
y3 = file ['OD3']
plt.plot(x,y1,label= 'OD1')
plt.plot(x,y2,label= 'OD2')
plt.plot(x,y3,label= 'OD3')
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xlabel('Time(min)', fontsize= 20)
plt.ylabel('OD', fontsize= 20)
plt.title('Raw Data')
plt.legend()

# %%
pip install scipy
# Out:
# ...
#                                               0.0/41.3 MB ? eta -:--:--
#                                               0.1/41.3 MB 2.0 MB/s eta 0:00:21
#                                               0.4/41.3 MB 5.3 MB/s eta 0:00:08
#                                               0.8/41.3 MB 6.6 MB/s eta 0:00:07
#      -                                        1.3/41.3 MB 7.3 MB/s eta 0:00:06
#      -                                        1.7/41.3 MB 7.6 MB/s eta 0:00:06
#      --                                       2.2/41.3 MB 8.9 MB/s eta 0:00:05
#      --                                       2.7/41.3 MB 9.5 MB/s eta 0:00:05
#      --                                       2.9/41.3 MB 9.0 MB/s eta 0:00:05
#      ---                                      3.3/41.3 MB 8.8 MB/s eta 0:00:05
#      ---                                      3.6/41.3 MB 8.9 MB/s eta 0:00:05
#      ----                                     4.2/41.3 MB 9.0 MB/s eta 0:00:05
# ...
